# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))

# %%
file = '/kaggle/input/zomato-reviews-ratings/zomato_reviews.csv'
df = pd.read_csv(file,usecols=['rating','review'])
print(f"Found {df.shape[0]} reviews with {df.rating.nunique()} ratings..")
# Out:
# Found 5479 reviews with 5 ratings..

# %%
df.head()
# Out:
#    rating                                             review
# 0       5                                               nice
# 1       5  best biryani , so supportive staff of outlet ,...
# 2       4     delivery boy was very decent and supportive.👌👍
# 3       1  worst biryani i have tasted in my life, half o...
# 4       5  all food is good and tasty . will order again ...

# %%
def plot_cloud(rating):
    temp = df[df['rating'] == rating]
    unique_string=(" ").join(temp['review'])
    wordcloud = WordCloud(width = 1500
                          ,height = 1000
                          ,background_color='white'
                          ,min_word_length=4
                         ,stopwords=stops
                          ,colormap ='hot').generate(unique_string)
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# # Prominent words in rating=5 reviews

# %%
plot_cloud(5)

# %% [markdown]
# # Prominent words in rating=1 reviews

# %%
plot_cloud(1)
